# %%
# !pip install spotipy

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id='e08812d0ad874b53bb01e49ada6166ad'
client_secret='9085378d43d24d6c823a92c0f2cb03b5'

# # 민진님
# client_id = "7a98ceda33624c9bb15bf7f877176e50"
# client_secret = "74fb60bce9d048e3a9faa52427e6d0f5"

# # 세인님
# client_id = "05c96c56746e49b9b26e2ccf9837c7b7"
# client_secret = "98238151cd5e46df93049946ddd3673a"


client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
# Out:
# ...
# DEPRECATION: pytorch-lightning 1.6.1 has a non-standard dependency specifier torch>=1.8.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # K-POP 기준으로 탑 50 가져오기

# %%
import pandas as pd
from pathlib import Path

artist_name = []
track_name = []
track_popularity = []
artist_id = []
track_id = []

total_tracks = 1000
limit_per_request = 50

for offset in range(0, total_tracks, limit_per_request):
    print(f"Processing offset: {offset}/{total_tracks}")

    track_results = sp.search(q='year:2023 genre:"k-pop"', type='track', limit=limit_per_request, offset=offset)
    
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        track_popularity.append(t['popularity'])

top_tracks = pd.DataFrame({
    'artist_name': artist_name,
    'artist_id': artist_id,
    'track_name': track_name,
    'track_id': track_id,
    'track_popularity': track_popularity
})

desktop_path = Path(r'C:\Users\figure.2\Desktop\class29\Project\spotify\data')
csv_path = desktop_path / 'kpop_top_tracks_2023.csv'

top_tracks.to_csv(csv_path, index=False)

print(f"CSV 파일이 성공적으로 저장되었습니다. 경로: {csv_path}")
# Out:
# Processing offset: 0/1000
# Processing offset: 50/1000
# Processing offset: 100/1000
# Processing offset: 150/1000
# Processing offset: 200/1000
# Processing offset: 250/1000
# Processing offset: 300/1000
# Processing offset: 350/1000
# Processing offset: 400/1000
# Processing offset: 450/1000
# Processing offset: 500/1000
# Processing offset: 550/1000
# Processing offset: 600/1000
# Processing offset: 650/1000
# Processing offset: 700/1000
# Processing offset: 750/1000
# Processing offset: 800/1000
# Processing offset: 850/1000
# Processing offset: 900/1000
# Processing offset: 950/1000
# CSV 파일이 성공적으로 저장되었습니다. 경로: C:\Users\figure.2\Desktop\class29\Project\spotify\data\kpop_tracks_2023.csv

# %%
artist_popularity = []
artist_genres = []
artist_followers =[]
for a_id in track_df.artist_id:
    artist = sp.artist(a_id)
    artist_popularity.append(artist['popularity'])
    artist_genres.append(artist['genres'])
    artist_followers.append(artist['followers']['total'])
    
artist_track = track_df.assign(artist_popularity=artist_popularity, artist_genres=artist_genres, artist_followers=artist_followers)
artist_track.head()

# %%
import pandas as pd
from pathlib import Path

artist_name = []
track_name = []
track_popularity = []
artist_id = []
track_id = []

total_tracks = 1000
limit_per_request = 50

for offset in range(0, total_tracks, limit_per_request):
    print(f"Processing offset: {offset}/{total_tracks}")

    track_results = sp.search(q='year:2023 genre:"k-pop"', type='track', limit=limit_per_request, offset=offset)
    
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        track_popularity.append(t['popularity'])

track_df = pd.DataFrame({
    'artist_name': artist_name,
    'artist_id': artist_id,
    'track_name': track_name,
    'track_id': track_id,
    'track_popularity': track_popularity
})

# artist
artist_popularity = []
artist_genres = []
artist_followers = []

for a_id in track_df.artist_id:
    artist = sp.artist(a_id)
    artist_popularity.append(artist['popularity'])
    artist_genres.append(artist['genres'])
    artist_followers.append(artist['followers']['total'])


track_df['artist_popularity'] = artist_popularity
track_df['artist_genres'] = artist_genres
track_df['artist_followers'] = artist_followers

# CSV 파일로 저장
desktop_path = Path(r'C:\Users\figure.2\Desktop\class29\Project\spotify')
csv_path = desktop_path / 'kpop_tracks_with_artist_info.csv'

track_df.to_csv(csv_path, index=False)

# 저장된 파일 확인
print(f"CSV 파일이 성공적으로 저장되었습니다. 경로: {csv_path}")
# Out:
# Processing offset: 0/1000
# Processing offset: 50/1000
# Processing offset: 100/1000
# Processing offset: 150/1000
# Processing offset: 200/1000
# Processing offset: 250/1000
# Processing offset: 300/1000
# Processing offset: 350/1000
# Processing offset: 400/1000
# Processing offset: 450/1000
# Processing offset: 500/1000
# Processing offset: 550/1000
# Processing offset: 600/1000
# Processing offset: 650/1000
# Processing offset: 700/1000
# Processing offset: 750/1000
# Processing offset: 800/1000
# Processing offset: 850/1000
# Processing offset: 900/1000
# Processing offset: 950/1000

# %%
track_features = []
for t_id in track_df['track_id']:
    af = sp.audio_features(t_id)
    track_features.append(af)
tf_df = pd.DataFrame(columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'url', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])
for item in track_features:
    for feat in item:
        tf_df = tf_df.append(feat, ignore_index=True)
tf_df.head()

# %%
import pandas as pd
#import gdown
import time

start_time = time.time()  


artist_name = []
track_name = []
track_popularity = []
artist_id = []
track_id = []

total_tracks = 1000
limit_per_request = 50

for offset in range(0, total_tracks, limit_per_request):
    print(f"Processing offset: {offset}/{total_tracks}")

    track_results = sp.search(q='year:2023 genre:"k-pop"', type='track', limit=limit_per_request, offset=offset)
    
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        track_popularity.append(t['popularity'])

track_df = pd.DataFrame({
    'artist_name': artist_name,
    'artist_id': artist_id,
    'track_name': track_name,
    'track_id': track_id,
    'track_popularity': track_popularity
})

## artist_info

artist_popularity = []
artist_genres = []
artist_followers = []

for a_id in track_df.artist_id:
    artist = sp.artist(a_id)
    artist_popularity.append(artist['popularity'])
    artist_genres.append(artist['genres'])
    artist_followers.append(artist['followers']['total'])


track_df['artist_popularity'] = artist_popularity
track_df['artist_genres'] = artist_genres
track_df['artist_followers'] = artist_followers

#drive_path = 'https://drive.google.com/drive/folders/1xohXWBRgAsiU1GM-kH_wDOHvNJTWxwHw'

desktop_path = Path(r'C:\Users\figure.2\Desktop\class29\Project\spotify')
csv_path = desktop_path / 'kpop_tracks_with_artist_info.csv'

track_df.to_csv(csv_path, index=False)

end_time = time.time() 
elapsed_time = end_time - start_time 


print(f"CSV 파일이 Google Drive에 성공적으로 저장되었습니다. 경로: {csv_path_drive}")
print(f"총 실행 시간: {elapsed_time:.2f} 초")

# %%
import time
import pandas as pd

# Spotify_Top_tracks
artist_name = []
track_name = []
track_popularity = []
artist_id = []
track_id = []
for offset in range(0, 1000, 50):
    track_results = sp.search(q='year:2023 genre:"k-pop"', type='track', limit=50, offset=offset)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        track_popularity.append(t['popularity'])

Spotify_Top_tracks = pd.DataFrame({'artist_name': artist_name, 'artist_id': artist_id, 'track_name': track_name, 'track_id': track_id, 'track_popularity': track_popularity})

# Spotify_Artists
artist_popularity = []
artist_genres = []
artist_followers = []
for a_id in Spotify_Top_tracks.artist_id:
    artist = sp.artist(a_id)
    artist_followers.append(artist['followers']['total'])
    artist_popularity.append(artist['popularity'])
    artist_genres.append(artist['genres'])

Spotify_Artists = Spotify_Top_tracks.assign(artist_followers=artist_followers, artist_popularity=artist_popularity, artist_genres=artist_genres)

# 오디오 특성 가져오기 전에 5분 대기 과도한 요청으로 API KEY 일시 정지를 막기 위해
time.sleep(360)

track_features = []
for t_id in Spotify_Artists['track_id']:
    af = sp.audio_features(t_id)
    track_features.append(af)
Spotify_API = pd.DataFrame(columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'url', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])
for item in track_features:
    for feat in item:
        Spotify_API = Spotify_API.append(feat, ignore_index=True)
Spotify_API.head()

Spotify_API = pd.DataFrame(track_features)

Spotify_API.head()

# %% [markdown]
# 플레이리스트 테스트
#
# 특정 플레이리스트의 id 한개 넣을때

# %%
playlist_id = '37i9dQZF1DX0A8zVl7p82B'

results = sp.playlist(playlist_id)
print("플레이리스트 제목: ", results['name'])
for idx, item in enumerate(results['tracks']['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'])

# %%
playlist_id = '37i9dQZF1DXe5W6diBL5N4'

results = sp.playlist(playlist_id)
print("플레이리스트 제목: ", results['name'])
for idx, item in enumerate(results['tracks']['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'])

# %% [markdown]
# https://open.spotify.com/search/k-pop/playlists
#
# 스포티파이 홈페이지에서 k-pop을 검색 후 검색창 아래 있는 플레이리스트 선택해서 들어간 홈페이지에 있는
#
# 플레이리스트 20개 가져온거

# %%
search_query = 'k-pop'
search_results = sp.search(search_query, type='playlist', limit=20)

for i, playlist in enumerate(search_results['playlists']['items']):
    print(f"{i+1}. {playlist['name']} - {playlist['id']}")

# %%
playlist_ids = [
    '37i9dQZF1EQpesGsmIyqcW',
    '37i9dQZF1DX9tPFwDMOaN1',
    '2EoheVFjqIxgJMb8VnDRtZ',
    '37i9dQZF1DX1LU4UHKqdtg',
    '37i9dQZF1DX4FcAKI5Nhzq',
    '37i9dQZF1DWYbyYXnUYgqZ',
    '4JcbaaznRdlWyzkXrDC7C6',
    '37i9dQZF1DX4IDaXtVjL83',
    '0jBy7AoqEFcY2xc57sSlTW',
    '37i9dQZF1DWTTXfIhcSkXG'
]

for playlist_id in playlist_ids:
    results = sp.playlist(playlist_id)
    print("플레이리스트 제목: ", results['name'])
    for idx, item in enumerate(results['tracks']['items']):
        track = item['track']
        print(idx, track['artists'][0]['name'], " – ", track['name'])
    print()

# %%
import pandas as pd

search_query = 'k-pop'
search_results = sp.search(search_query, type='playlist', limit= 3 )

playlist_ids = [playlist['id'] for playlist in search_results['playlists']['items']]

data = []
for playlist_id in playlist_ids:
    results = sp.playlist(playlist_id)
    for idx, item in enumerate(results['tracks']['items']):
        track = item['track']
        if track is None:
            continue
        data.append([results['name'], track['artists'][0]['name'], track['name']])

df = pd.DataFrame(data, columns=['Playlist', 'Artist', 'Song'])

df.to_csv('spotify_playlist.csv', index=False, encoding='utf-8-sig')

# %%
import pandas as pd

search_query = 'k-pop'
search_results = sp.search(search_query, type='playlist', limit=2)

playlist_ids = [playlist['id'] for playlist in search_results['playlists']['items']]

data = []
for playlist_id in playlist_ids:
    results = sp.playlist(playlist_id)
    print("플레이리스트 제목:", results['name'])

    for track in results['tracks']['items']:
        if track['track'] is not None:
            data.append([results['name'], track['track']['artists'][0]['name'], track['track']['name']])
            print(track['track']['artists'][0]['name'], "–", track['track']['name'])
    print()

df = pd.DataFrame(data, columns=['Playlist', 'Artist', 'Song'])

df.head(10)
# Out:
# 플레이리스트 제목: K-Pop Mix
# (G)I-DLE – I Want That
# FIFTY FIFTY – Cupid – Twin Ver. (feat. Sabrina Carpenter)
# Stray Kids – LALALALA
# Girls' Generation – Gee
# NewJeans – Hype Boy
# KARD – Bomb Bomb
# BTS – Run BTS
# Red Velvet – Peek-A-Boo
# ENHYPEN – Bite Me
# MONSTA X – HERO
# AOA – Like a Cat
# EVERGLOW – DUN DUN
# aespa – Savage
# JISOO – FLOWER
# VIXX – Chained Up
# KARD – Oh NaNa (Hidden. HUR YOUNG JI)
# Red Velvet – Psycho
# OH MY GIRL – Nonstop
# EVERGLOW – FIRST
# EXO – Obsession
# Orange Caramel – Catallena
# PSY – That That (prod.&feat. SUGA of BTS)
# NU'EST – FACE
# Block B – 닐리리맘보
# OH MY GIRL – Dolphin
# Weeekly – After School
# NCT – BOSS
# (G)I-DLE – MY BAG
# TOMORROW X TOGETHER – Tinnitus (Wanna be a rock)
# NAYEON – POP!
# BTS – Boy With Luv (feat. Halsey)
# TAEMIN – MOVE
# CLC – Hobgoblin
# Red Velvet – Bad Boy
# SUNMI – Heroine
# GOT7 – Hard Carry
# SISTAR – SHAKE IT
# BTS – MIC Drop (Steve Aoki Remix) - Full Length Edition
# CIX – Movie Star
# Apink – Mr. Chu
# ...
