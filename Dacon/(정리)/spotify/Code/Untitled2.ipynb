# %%
# !pip install spotipy

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd
import time
import datetime
import os

# client_id='e08812d0ad874b53bb01e49ada6166ad'
# client_secret='9085378d43d24d6c823a92c0f2cb03b5'

# # # 민진님
# # client_id = "7a98ceda33624c9bb15bf7f877176e50"
# # client_secret = "74fb60bce9d048e3a9faa52427e6d0f5"

# # 세인님
# client_id = "05c96c56746e49b9b26e2ccf9837c7b7"
# client_secret = "98238151cd5e46df93049946ddd3673a"

# # 서브 1
# client_id = "55cc1bbf202640ee8a691ecab9be6e1d"
# client_secret = "ef892d15d19543f4840c5ff069e6503c"

# # 서브 2
# client_id = "37211c9678ae40e6aed26be454135b1e"
# client_secret = "031a960bb8bc4367a412f63d25f1f513"

# 서브 3
client_id = "4cda4cd5cf9a4877b55336bedbe21c9c"
client_secret = "93bacd33bd494ec5bc76034f3705d502"

# # 서브 4
# client_id = "9e6e9e6622204dbe85e2553c9b026ed5"
# client_secret = "b7b96ff10fae4077ab8912e1fb9d1f6b"

# # 서브 5
# client_id = "8e564786163d4a66a8e8d844955b9c2d"
# client_secret = "7966e74a259d4fd9a3d689b54fd3d100"

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
# Out:
# Requirement already satisfied: spotipy in c:\users\figure.2\appdata\local\programs\python\python311\lib\site-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\figure.2\appdata\local\programs\python\python311\lib\site-packages (from spotipy) (5.0.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\figure.2\appdata\local\programs\python\python311\lib\site-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\figure.2\appdata\local\programs\python\python311\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\figure.2\appdata\local\programs\python\python311\lib\site-packages (from spotipy) (2.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\figure.2\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.25.0->spotipy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\figure.2\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\figure.2\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.25.0->spotipy) (2023.7.22)

# %%
import pandas as pd



# Set up your query parameters
genre = 'k-pop'
limit = 5

# Get the top tracks in the K-pop genre
top_tracks = sp.search(q=f'genre:"{genre}"', type='track', limit=limit)

# Initialize empty lists for track features and audio analysis
track_features_list = []
audio_analysis_list = []

# Iterate over the top tracks and retrieve track features and audio analysis
for track in top_tracks['tracks']['items']:
    track_id = track['id']
    
    # Get track features
    track_features = sp.audio_features(track_id)[0]
    track_features_list.append(track_features)
    
    # Get audio analysis
    audio_analysis = sp.audio_analysis(track_id)
    audio_analysis_list.append(audio_analysis)

# Create DataFrames for track features and audio analysis
track_features_df = pd.DataFrame(track_features_list)
audio_analysis_df = pd.DataFrame(audio_analysis_list)

# Print the DataFrames
print("Track Features:")
print(track_features_df)
track_features_df.head()

print("\nAudio Analysis:")
print(audio_analysis_df)
# Out:
# Track Features:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.943   0.558    2    -4.911     1       0.0568        0.0026
# 1         0.711   0.809    2    -4.389     0       0.0955        0.0447
# 2         0.629   0.733    7    -5.445     1       0.0419        0.0025
# 3         0.697   0.820    5    -4.502     1       0.0308        0.1000
# 4         0.629   0.733    7    -5.445     1       0.0419        0.0025
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000002    0.0937    0.606  104.983  audio_features
# 1          0.000000    0.3390    0.816  106.017  audio_features
# 2          0.000000    0.3570    0.362  120.001  audio_features
# 3          0.000000    0.0631    0.502  136.054  audio_features
# 4          0.000000    0.3570    0.362  120.001  audio_features
#
#                        id                                   uri  \
# 0  4xhsWYTOGcal8zt0J161CU  spotify:track:4xhsWYTOGcal8zt0J161CU
# 1  2KslE17cAJNHTsI2MI0jb2  spotify:track:2KslE17cAJNHTsI2MI0jb2
# 2  3Ua0m0YmEjrMi9XErKcNiR  spotify:track:3Ua0m0YmEjrMi9XErKcNiR
# 3  74X2u8JMVooG2QbjRxXwR8  spotify:track:74X2u8JMVooG2QbjRxXwR8
# 4  58BWnoFDNaeM0vwA0K3fqb  spotify:track:58BWnoFDNaeM0vwA0K3fqb
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 1  https://api.spotify.com/v1/tracks/2KslE17cAJNH...
# 2  https://api.spotify.com/v1/tracks/3Ua0m0YmEjrM...
# 3  https://api.spotify.com/v1/tracks/74X2u8JMVooG...
# 4  https://api.spotify.com/v1/tracks/58BWnoFDNaeM...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 1  https://api.spotify.com/v1/audio-analysis/2Ksl...       206020
# 2  https://api.spotify.com/v1/audio-analysis/3Ua0...       212241
# 3  https://api.spotify.com/v1/audio-analysis/74X2...       159080
# 4  https://api.spotify.com/v1/audio-analysis/58BW...       212241
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# Audio Analysis:
#                                                 meta  \
# 0  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 1  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 2  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 3  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 4  {'analyzer_version': '4.0.0', 'platform': 'Lin...
#
#                                                track  \
# 0  {'num_samples': 3051969, 'duration': 138.41129...
# 1  {'num_samples': 4542732, 'duration': 206.01959...
# 2  {'num_samples': 4679923, 'duration': 212.24141...
# 3  {'num_samples': 3507719, 'duration': 159.08023...
# 4  {'num_samples': 4679923, 'duration': 212.24141...
#
#                                                 bars  \
# 0  [{'start': 1.0631, 'duration': 2.28425, 'confi...
# 1  [{'start': 0.2819, 'duration': 2.24926, 'confi...
# 2  [{'start': 2.31979, 'duration': 1.98956, 'conf...
# 3  [{'start': 0.24185, 'duration': 1.77485, 'conf...
# 4  [{'start': 2.31979, 'duration': 1.98956, 'conf...
#
#                                                beats  \
# 0  [{'start': 0.48305, 'duration': 0.58006, 'conf...
# 1  [{'start': 0.2819, 'duration': 0.55995, 'confi...
# 2  [{'start': 0.79008, 'duration': 0.52043, 'conf...
# 3  [{'start': 0.24185, 'duration': 0.44235, 'conf...
# 4  [{'start': 0.79008, 'duration': 0.52043, 'conf...
#
#                                             sections  \
# 0  [{'start': 0.0, 'duration': 9.0698, 'confidenc...
# 1  [{'start': 0.0, 'duration': 19.5134, 'confiden...
# 2  [{'start': 0.0, 'duration': 15.8124, 'confiden...
# 3  [{'start': 0.0, 'duration': 8.19599, 'confiden...
# 4  [{'start': 0.0, 'duration': 15.8124, 'confiden...
#
#                                             segments  \
# 0  [{'start': 0.0, 'duration': 0.18571, 'confiden...
# 1  [{'start': 0.0, 'duration': 0.25664, 'confiden...
# 2  [{'start': 0.0, 'duration': 0.24408, 'confiden...
# 3  [{'start': 0.0, 'duration': 0.2327, 'confidenc...
# 4  [{'start': 0.0, 'duration': 0.24408, 'confiden...
#
#                                               tatums
# 0  [{'start': 0.48305, 'duration': 0.29003, 'conf...
# 1  [{'start': 0.2819, 'duration': 0.27997, 'confi...
# 2  [{'start': 0.79008, 'duration': 0.26021, 'conf...
# 3  [{'start': 0.24185, 'duration': 0.22117, 'conf...
# 4  [{'start': 0.79008, 'duration': 0.26021, 'conf...

# %%
track_features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.943   0.558    2    -4.911     1       0.0568        0.0026
# 1         0.711   0.809    2    -4.389     0       0.0955        0.0447
# 2         0.629   0.733    7    -5.445     1       0.0419        0.0025
# 3         0.697   0.820    5    -4.502     1       0.0308        0.1000
# 4         0.629   0.733    7    -5.445     1       0.0419        0.0025
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000002    0.0937    0.606  104.983  audio_features
# 1          0.000000    0.3390    0.816  106.017  audio_features
# 2          0.000000    0.3570    0.362  120.001  audio_features
# 3          0.000000    0.0631    0.502  136.054  audio_features
# 4          0.000000    0.3570    0.362  120.001  audio_features
#
#                        id                                   uri  \
# 0  4xhsWYTOGcal8zt0J161CU  spotify:track:4xhsWYTOGcal8zt0J161CU
# 1  2KslE17cAJNHTsI2MI0jb2  spotify:track:2KslE17cAJNHTsI2MI0jb2
# 2  3Ua0m0YmEjrMi9XErKcNiR  spotify:track:3Ua0m0YmEjrMi9XErKcNiR
# 3  74X2u8JMVooG2QbjRxXwR8  spotify:track:74X2u8JMVooG2QbjRxXwR8
# 4  58BWnoFDNaeM0vwA0K3fqb  spotify:track:58BWnoFDNaeM0vwA0K3fqb
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 1  https://api.spotify.com/v1/tracks/2KslE17cAJNH...
# 2  https://api.spotify.com/v1/tracks/3Ua0m0YmEjrM...
# 3  https://api.spotify.com/v1/tracks/74X2u8JMVooG...
# 4  https://api.spotify.com/v1/tracks/58BWnoFDNaeM...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 1  https://api.spotify.com/v1/audio-analysis/2Ksl...       206020
# 2  https://api.spotify.com/v1/audio-analysis/3Ua0...       212241
# 3  https://api.spotify.com/v1/audio-analysis/74X2...       159080
# 4  https://api.spotify.com/v1/audio-analysis/58BW...       212241
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
audio_analysis_df.head()
# Out:
#                                                 meta  \
# 0  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 1  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 2  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 3  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 4  {'analyzer_version': '4.0.0', 'platform': 'Lin...
#
#                                                track  \
# 0  {'num_samples': 3051969, 'duration': 138.41129...
# 1  {'num_samples': 4542732, 'duration': 206.01959...
# 2  {'num_samples': 4679923, 'duration': 212.24141...
# 3  {'num_samples': 3507719, 'duration': 159.08023...
# 4  {'num_samples': 4679923, 'duration': 212.24141...
#
#                                                 bars  \
# 0  [{'start': 1.0631, 'duration': 2.28425, 'confi...
# 1  [{'start': 0.2819, 'duration': 2.24926, 'confi...
# 2  [{'start': 2.31979, 'duration': 1.98956, 'conf...
# 3  [{'start': 0.24185, 'duration': 1.77485, 'conf...
# 4  [{'start': 2.31979, 'duration': 1.98956, 'conf...
#
#                                                beats  \
# 0  [{'start': 0.48305, 'duration': 0.58006, 'conf...
# 1  [{'start': 0.2819, 'duration': 0.55995, 'confi...
# 2  [{'start': 0.79008, 'duration': 0.52043, 'conf...
# 3  [{'start': 0.24185, 'duration': 0.44235, 'conf...
# 4  [{'start': 0.79008, 'duration': 0.52043, 'conf...
#
#                                             sections  \
# 0  [{'start': 0.0, 'duration': 9.0698, 'confidenc...
# 1  [{'start': 0.0, 'duration': 19.5134, 'confiden...
# 2  [{'start': 0.0, 'duration': 15.8124, 'confiden...
# 3  [{'start': 0.0, 'duration': 8.19599, 'confiden...
# 4  [{'start': 0.0, 'duration': 15.8124, 'confiden...
#
#                                             segments  \
# 0  [{'start': 0.0, 'duration': 0.18571, 'confiden...
# 1  [{'start': 0.0, 'duration': 0.25664, 'confiden...
# 2  [{'start': 0.0, 'duration': 0.24408, 'confiden...
# 3  [{'start': 0.0, 'duration': 0.2327, 'confidenc...
# 4  [{'start': 0.0, 'duration': 0.24408, 'confiden...
#
#                                               tatums
# 0  [{'start': 0.48305, 'duration': 0.29003, 'conf...
# 1  [{'start': 0.2819, 'duration': 0.27997, 'confi...
# 2  [{'start': 0.79008, 'duration': 0.26021, 'conf...
# 3  [{'start': 0.24185, 'duration': 0.22117, 'conf...
# 4  [{'start': 0.79008, 'duration': 0.26021, 'conf...

# %%
import pandas as pd

# Set up your query parameters
genre = 'k-pop'
limit = 5

# Get the top tracks in the K-pop genre
top_tracks = sp.search(q=f'genre:"{genre}"', type='track', limit=limit)

# Initialize an empty dictionary for audio analysis
audio_analysis_dict = {}

# Iterate over the top tracks and retrieve track features and audio analysis
for track in top_tracks['tracks']['items']:
    track_id = track['id']
    
    # Get track features
    track_features = sp.audio_features(track_id)[0]
    track_features_list.append(track_features)
    
    # Get audio analysis
    audio_analysis = sp.audio_analysis(track_id)
    
    # Add each key-value pair in audio_analysis to audio_analysis_dict
    for key, value in audio_analysis.items():
        if key not in audio_analysis_dict:
            audio_analysis_dict[key] = [value]
        else:
            audio_analysis_dict[key].append(value)

# Create DataFrame for track features
track_features2_df = pd.DataFrame(track_features_list)

# Create DataFrame for audio analysis
audio_analysis2_df = pd.DataFrame(audio_analysis_dict)

# Print the DataFrames
print("Track Features:")
print(track_features2_df)


print("Audio Analysis:")
print(audio_analysis2_df)
# Out:
# Track Features:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.943   0.558    2    -4.911     1       0.0568        0.0026
# 1          0.711   0.809    2    -4.389     0       0.0955        0.0447
# 2          0.629   0.733    7    -5.445     1       0.0419        0.0025
# 3          0.697   0.820    5    -4.502     1       0.0308        0.1000
# 4          0.629   0.733    7    -5.445     1       0.0419        0.0025
# 5          0.943   0.558    2    -4.911     1       0.0568        0.0026
# 6          0.711   0.809    2    -4.389     0       0.0955        0.0447
# 7          0.629   0.733    7    -5.445     1       0.0419        0.0025
# 8          0.697   0.820    5    -4.502     1       0.0308        0.1000
# 9          0.629   0.733    7    -5.445     1       0.0419        0.0025
# 10         0.943   0.558    2    -4.911     1       0.0568        0.0026
# 11         0.711   0.809    2    -4.389     0       0.0955        0.0447
# 12         0.629   0.733    7    -5.445     1       0.0419        0.0025
# 13         0.697   0.820    5    -4.502     1       0.0308        0.1000
# 14         0.629   0.733    7    -5.445     1       0.0419        0.0025
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000002    0.0937    0.606  104.983  audio_features
# 1           0.000000    0.3390    0.816  106.017  audio_features
# 2           0.000000    0.3570    0.362  120.001  audio_features
# 3           0.000000    0.0631    0.502  136.054  audio_features
# 4           0.000000    0.3570    0.362  120.001  audio_features
# 5           0.000002    0.0937    0.606  104.983  audio_features
# 6           0.000000    0.3390    0.816  106.017  audio_features
# 7           0.000000    0.3570    0.362  120.001  audio_features
# 8           0.000000    0.0631    0.502  136.054  audio_features
# 9           0.000000    0.3570    0.362  120.001  audio_features
# 10          0.000002    0.0937    0.606  104.983  audio_features
# 11          0.000000    0.3390    0.816  106.017  audio_features
# 12          0.000000    0.3570    0.362  120.001  audio_features
# 13          0.000000    0.0631    0.502  136.054  audio_features
# 14          0.000000    0.3570    0.362  120.001  audio_features
#
#                         id                                   uri  \
# 0   4xhsWYTOGcal8zt0J161CU  spotify:track:4xhsWYTOGcal8zt0J161CU
# 1   2KslE17cAJNHTsI2MI0jb2  spotify:track:2KslE17cAJNHTsI2MI0jb2
# 2   3Ua0m0YmEjrMi9XErKcNiR  spotify:track:3Ua0m0YmEjrMi9XErKcNiR
# 3   74X2u8JMVooG2QbjRxXwR8  spotify:track:74X2u8JMVooG2QbjRxXwR8
# 4   58BWnoFDNaeM0vwA0K3fqb  spotify:track:58BWnoFDNaeM0vwA0K3fqb
# 5   4xhsWYTOGcal8zt0J161CU  spotify:track:4xhsWYTOGcal8zt0J161CU
# 6   2KslE17cAJNHTsI2MI0jb2  spotify:track:2KslE17cAJNHTsI2MI0jb2
# 7   3Ua0m0YmEjrMi9XErKcNiR  spotify:track:3Ua0m0YmEjrMi9XErKcNiR
# 8   74X2u8JMVooG2QbjRxXwR8  spotify:track:74X2u8JMVooG2QbjRxXwR8
# 9   58BWnoFDNaeM0vwA0K3fqb  spotify:track:58BWnoFDNaeM0vwA0K3fqb
# 10  4xhsWYTOGcal8zt0J161CU  spotify:track:4xhsWYTOGcal8zt0J161CU
# 11  2KslE17cAJNHTsI2MI0jb2  spotify:track:2KslE17cAJNHTsI2MI0jb2
# 12  3Ua0m0YmEjrMi9XErKcNiR  spotify:track:3Ua0m0YmEjrMi9XErKcNiR
# 13  74X2u8JMVooG2QbjRxXwR8  spotify:track:74X2u8JMVooG2QbjRxXwR8
# 14  58BWnoFDNaeM0vwA0K3fqb  spotify:track:58BWnoFDNaeM0vwA0K3fqb
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 1   https://api.spotify.com/v1/tracks/2KslE17cAJNH...
# 2   https://api.spotify.com/v1/tracks/3Ua0m0YmEjrM...
# 3   https://api.spotify.com/v1/tracks/74X2u8JMVooG...
# 4   https://api.spotify.com/v1/tracks/58BWnoFDNaeM...
# 5   https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 6   https://api.spotify.com/v1/tracks/2KslE17cAJNH...
# 7   https://api.spotify.com/v1/tracks/3Ua0m0YmEjrM...
# 8   https://api.spotify.com/v1/tracks/74X2u8JMVooG...
# 9   https://api.spotify.com/v1/tracks/58BWnoFDNaeM...
# 10  https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 11  https://api.spotify.com/v1/tracks/2KslE17cAJNH...
# 12  https://api.spotify.com/v1/tracks/3Ua0m0YmEjrM...
# 13  https://api.spotify.com/v1/tracks/74X2u8JMVooG...
# 14  https://api.spotify.com/v1/tracks/58BWnoFDNaeM...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 1   https://api.spotify.com/v1/audio-analysis/2Ksl...       206020
# 2   https://api.spotify.com/v1/audio-analysis/3Ua0...       212241
# 3   https://api.spotify.com/v1/audio-analysis/74X2...       159080
# 4   https://api.spotify.com/v1/audio-analysis/58BW...       212241
# 5   https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 6   https://api.spotify.com/v1/audio-analysis/2Ksl...       206020
# 7   https://api.spotify.com/v1/audio-analysis/3Ua0...       212241
# 8   https://api.spotify.com/v1/audio-analysis/74X2...       159080
# 9   https://api.spotify.com/v1/audio-analysis/58BW...       212241
# 10  https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 11  https://api.spotify.com/v1/audio-analysis/2Ksl...       206020
# 12  https://api.spotify.com/v1/audio-analysis/3Ua0...       212241
# 13  https://api.spotify.com/v1/audio-analysis/74X2...       159080
# 14  https://api.spotify.com/v1/audio-analysis/58BW...       212241
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                4
# 10               4
# 11               4
# 12               4
# 13               4
# 14               4
# Audio Analysis:
#                                                 meta  \
# 0  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 1  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 2  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 3  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 4  {'analyzer_version': '4.0.0', 'platform': 'Lin...
#
#                                                track  \
# 0  {'num_samples': 3051969, 'duration': 138.41129...
# 1  {'num_samples': 4542732, 'duration': 206.01959...
# 2  {'num_samples': 4679923, 'duration': 212.24141...
# 3  {'num_samples': 3507719, 'duration': 159.08023...
# 4  {'num_samples': 4679923, 'duration': 212.24141...
#
#                                                 bars  \
# 0  [{'start': 1.0631, 'duration': 2.28425, 'confi...
# 1  [{'start': 0.2819, 'duration': 2.24926, 'confi...
# 2  [{'start': 2.31979, 'duration': 1.98956, 'conf...
# 3  [{'start': 0.24185, 'duration': 1.77485, 'conf...
# 4  [{'start': 2.31979, 'duration': 1.98956, 'conf...
#
#                                                beats  \
# 0  [{'start': 0.48305, 'duration': 0.58006, 'conf...
# 1  [{'start': 0.2819, 'duration': 0.55995, 'confi...
# 2  [{'start': 0.79008, 'duration': 0.52043, 'conf...
# 3  [{'start': 0.24185, 'duration': 0.44235, 'conf...
# 4  [{'start': 0.79008, 'duration': 0.52043, 'conf...
#
#                                             sections  \
# 0  [{'start': 0.0, 'duration': 9.0698, 'confidenc...
# 1  [{'start': 0.0, 'duration': 19.5134, 'confiden...
# 2  [{'start': 0.0, 'duration': 15.8124, 'confiden...
# 3  [{'start': 0.0, 'duration': 8.19599, 'confiden...
# 4  [{'start': 0.0, 'duration': 15.8124, 'confiden...
#
#                                             segments  \
# 0  [{'start': 0.0, 'duration': 0.18571, 'confiden...
# 1  [{'start': 0.0, 'duration': 0.25664, 'confiden...
# 2  [{'start': 0.0, 'duration': 0.24408, 'confiden...
# 3  [{'start': 0.0, 'duration': 0.2327, 'confidenc...
# 4  [{'start': 0.0, 'duration': 0.24408, 'confiden...
#
#                                               tatums
# 0  [{'start': 0.48305, 'duration': 0.29003, 'conf...
# 1  [{'start': 0.2819, 'duration': 0.27997, 'confi...
# 2  [{'start': 0.79008, 'duration': 0.26021, 'conf...
# 3  [{'start': 0.24185, 'duration': 0.22117, 'conf...
# 4  [{'start': 0.79008, 'duration': 0.26021, 'conf...

# %%
track_features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.943   0.558    2    -4.911     1       0.0568        0.0026
# 1         0.711   0.809    2    -4.389     0       0.0955        0.0447
# 2         0.629   0.733    7    -5.445     1       0.0419        0.0025
# 3         0.697   0.820    5    -4.502     1       0.0308        0.1000
# 4         0.629   0.733    7    -5.445     1       0.0419        0.0025
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000002    0.0937    0.606  104.983  audio_features
# 1          0.000000    0.3390    0.816  106.017  audio_features
# 2          0.000000    0.3570    0.362  120.001  audio_features
# 3          0.000000    0.0631    0.502  136.054  audio_features
# 4          0.000000    0.3570    0.362  120.001  audio_features
#
#                        id                                   uri  \
# 0  4xhsWYTOGcal8zt0J161CU  spotify:track:4xhsWYTOGcal8zt0J161CU
# 1  2KslE17cAJNHTsI2MI0jb2  spotify:track:2KslE17cAJNHTsI2MI0jb2
# 2  3Ua0m0YmEjrMi9XErKcNiR  spotify:track:3Ua0m0YmEjrMi9XErKcNiR
# 3  74X2u8JMVooG2QbjRxXwR8  spotify:track:74X2u8JMVooG2QbjRxXwR8
# 4  58BWnoFDNaeM0vwA0K3fqb  spotify:track:58BWnoFDNaeM0vwA0K3fqb
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 1  https://api.spotify.com/v1/tracks/2KslE17cAJNH...
# 2  https://api.spotify.com/v1/tracks/3Ua0m0YmEjrM...
# 3  https://api.spotify.com/v1/tracks/74X2u8JMVooG...
# 4  https://api.spotify.com/v1/tracks/58BWnoFDNaeM...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 1  https://api.spotify.com/v1/audio-analysis/2Ksl...       206020
# 2  https://api.spotify.com/v1/audio-analysis/3Ua0...       212241
# 3  https://api.spotify.com/v1/audio-analysis/74X2...       159080
# 4  https://api.spotify.com/v1/audio-analysis/58BW...       212241
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
audio_analysis_df.head()
# Out:
#                                                 meta  \
# 0  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 1  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 2  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 3  {'analyzer_version': '4.0.0', 'platform': 'Lin...
# 4  {'analyzer_version': '4.0.0', 'platform': 'Lin...
#
#                                                track  \
# 0  {'num_samples': 3051969, 'duration': 138.41129...
# 1  {'num_samples': 4542732, 'duration': 206.01959...
# 2  {'num_samples': 4679923, 'duration': 212.24141...
# 3  {'num_samples': 3507719, 'duration': 159.08023...
# 4  {'num_samples': 4679923, 'duration': 212.24141...
#
#                                                 bars  \
# 0  [{'start': 1.0631, 'duration': 2.28425, 'confi...
# 1  [{'start': 0.2819, 'duration': 2.24926, 'confi...
# 2  [{'start': 2.31979, 'duration': 1.98956, 'conf...
# 3  [{'start': 0.24185, 'duration': 1.77485, 'conf...
# 4  [{'start': 2.31979, 'duration': 1.98956, 'conf...
#
#                                                beats  \
# 0  [{'start': 0.48305, 'duration': 0.58006, 'conf...
# 1  [{'start': 0.2819, 'duration': 0.55995, 'confi...
# 2  [{'start': 0.79008, 'duration': 0.52043, 'conf...
# 3  [{'start': 0.24185, 'duration': 0.44235, 'conf...
# 4  [{'start': 0.79008, 'duration': 0.52043, 'conf...
#
#                                             sections  \
# 0  [{'start': 0.0, 'duration': 9.0698, 'confidenc...
# 1  [{'start': 0.0, 'duration': 19.5134, 'confiden...
# 2  [{'start': 0.0, 'duration': 15.8124, 'confiden...
# 3  [{'start': 0.0, 'duration': 8.19599, 'confiden...
# 4  [{'start': 0.0, 'duration': 15.8124, 'confiden...
#
#                                             segments  \
# 0  [{'start': 0.0, 'duration': 0.18571, 'confiden...
# 1  [{'start': 0.0, 'duration': 0.25664, 'confiden...
# 2  [{'start': 0.0, 'duration': 0.24408, 'confiden...
# 3  [{'start': 0.0, 'duration': 0.2327, 'confidenc...
# 4  [{'start': 0.0, 'duration': 0.24408, 'confiden...
#
#                                               tatums
# 0  [{'start': 0.48305, 'duration': 0.29003, 'conf...
# 1  [{'start': 0.2819, 'duration': 0.27997, 'confi...
# 2  [{'start': 0.79008, 'duration': 0.26021, 'conf...
# 3  [{'start': 0.24185, 'duration': 0.22117, 'conf...
# 4  [{'start': 0.79008, 'duration': 0.26021, 'conf...

# %%
import pandas as pd


# Set up your query parameters
genre = 'k-pop'
limit = 5

# Get the top tracks in the K-pop genre
top_tracks = sp.search(q=f'genre:"{genre}"', type='track', limit=limit)

# Initialize empty lists for track features and audio analysis
track_features_list = []
audio_analysis_list = []

# Iterate over the top tracks and retrieve track features and audio analysis
for track in top_tracks['tracks']['items']:
    track_id = track['id']
    
    # Get track features
    track_features = sp.audio_features(track_id)[0]
    track_features_list.append(track_features)
    
    # Get audio analysis
    audio_analysis = sp.audio_analysis(track_id)
    
    # Flatten the audio analysis dictionary and append to the list
    flattened_audio_analysis = {}
    for key, value in audio_analysis.items():
        if isinstance(value, dict):
            for subkey, subvalue in value.items():
                flattened_audio_analysis[f"{key}_{subkey}"] = subvalue
        else:
            flattened_audio_analysis[key] = value
    
    audio_analysis_list.append(flattened_audio_analysis)

# Create DataFrames for track features and flattened audio analysis
track_features_df = pd.DataFrame(track_features_list)
audio_analysis_df = pd.DataFrame(audio_analysis_list)

# %%
track_features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.943   0.558    2    -4.911     1       0.0568        0.0026
# 1         0.711   0.809    2    -4.389     0       0.0955        0.0447
# 2         0.629   0.733    7    -5.445     1       0.0419        0.0025
# 3         0.697   0.820    5    -4.502     1       0.0308        0.1000
# 4         0.629   0.733    7    -5.445     1       0.0419        0.0025
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000002    0.0937    0.606  104.983  audio_features
# 1          0.000000    0.3390    0.816  106.017  audio_features
# 2          0.000000    0.3570    0.362  120.001  audio_features
# 3          0.000000    0.0631    0.502  136.054  audio_features
# 4          0.000000    0.3570    0.362  120.001  audio_features
#
#                        id                                   uri  \
# 0  4xhsWYTOGcal8zt0J161CU  spotify:track:4xhsWYTOGcal8zt0J161CU
# 1  2KslE17cAJNHTsI2MI0jb2  spotify:track:2KslE17cAJNHTsI2MI0jb2
# 2  3Ua0m0YmEjrMi9XErKcNiR  spotify:track:3Ua0m0YmEjrMi9XErKcNiR
# 3  74X2u8JMVooG2QbjRxXwR8  spotify:track:74X2u8JMVooG2QbjRxXwR8
# 4  58BWnoFDNaeM0vwA0K3fqb  spotify:track:58BWnoFDNaeM0vwA0K3fqb
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 1  https://api.spotify.com/v1/tracks/2KslE17cAJNH...
# 2  https://api.spotify.com/v1/tracks/3Ua0m0YmEjrM...
# 3  https://api.spotify.com/v1/tracks/74X2u8JMVooG...
# 4  https://api.spotify.com/v1/tracks/58BWnoFDNaeM...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 1  https://api.spotify.com/v1/audio-analysis/2Ksl...       206020
# 2  https://api.spotify.com/v1/audio-analysis/3Ua0...       212241
# 3  https://api.spotify.com/v1/audio-analysis/74X2...       159080
# 4  https://api.spotify.com/v1/audio-analysis/58BW...       212241
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
audio_analysis_df.head(3)
# Out:
#   meta_analyzer_version meta_platform meta_detailed_status  meta_status_code  \
# 0                 4.0.0         Linux                   OK                 0
# 1                 4.0.0         Linux                   OK                 0
# 2                 4.0.0         Linux                   OK                 0
#
#    meta_timestamp  meta_analysis_time              meta_input_process  \
# 0      1698436284             8.92427  libvorbisfile L+R 44100->22050
# 1      1697752007            10.05695  libvorbisfile L+R 44100->22050
# 2      1678742516             9.14170  libvorbisfile L+R 44100->22050
#
#    track_num_samples  track_duration track_sample_md5  ...  \
# 0            3051969       138.41129                   ...
# 1            4542732       206.01959                   ...
# 2            4679923       212.24141                   ...
#
#    track_echoprint_version                                  track_synchstring  \
# 0                     4.12  eJxNVwm24zAIu4qPEBZv97_YIAn3z2ubJl6wDZIg7t_8Ro...
# 1                     4.12  eJxVmgl25CAMRK_iIxix3_9ig34V7szLTMdtYxBaSiWRiL...
# 2                     4.12  eJxFmImV7DoIRFNxCNaClvwTG-oW7jn_v-4eW0IIimLp_Y...
#
#    track_synch_version                                 track_rhythmstring  \
# 0                  1.0  eJytWlmWIzcMu0odQfty_4uFAEiV3O2Z5CPvZeJ2ubSQBM...
# 1                  1.0  eJx1XAmS4zquvIqPIC7gcv-LfeYCStVvfsTrcdmWKRJrIg...
# 2                  1.0  eJx9XAmy5LoNu4qPIFH7_S8WAiBl95skVT81r91uWeIKgn...
#
#    track_rhythm_version                                               bars  \
# 0                   1.0  [{'start': 1.0631, 'duration': 2.28425, 'confi...
# 1                   1.0  [{'start': 0.2819, 'duration': 2.24926, 'confi...
# 2                   1.0  [{'start': 2.31979, 'duration': 1.98956, 'conf...
#
#                                                beats  \
# 0  [{'start': 0.48305, 'duration': 0.58006, 'conf...
# 1  [{'start': 0.2819, 'duration': 0.55995, 'confi...
# 2  [{'start': 0.79008, 'duration': 0.52043, 'conf...
#
#                                             sections  \
# 0  [{'start': 0.0, 'duration': 9.0698, 'confidenc...
# 1  [{'start': 0.0, 'duration': 19.5134, 'confiden...
# 2  [{'start': 0.0, 'duration': 15.8124, 'confiden...
#
#                                             segments  \
# 0  [{'start': 0.0, 'duration': 0.18571, 'confiden...
# 1  [{'start': 0.0, 'duration': 0.25664, 'confiden...
# 2  [{'start': 0.0, 'duration': 0.24408, 'confiden...
#
#                                               tatums
# 0  [{'start': 0.48305, 'duration': 0.29003, 'conf...
# 1  [{'start': 0.2819, 'duration': 0.27997, 'confi...
# 2  [{'start': 0.79008, 'duration': 0.26021, 'conf...
#
# [3 rows x 38 columns]

# %%
# Set up your query parameters
genre = 'k-pop'
limit = 5

# Get the top tracks in the K-pop genre
top_tracks = sp.search(q=f'genre:"{genre}"', type='track', limit=limit)

# Initialize empty lists for track features and audio analysis
track_features_list = []
audio_analysis_list = []

# Iterate over the top tracks and retrieve track features and audio analysis
for track in top_tracks['tracks']['items']:
    track_id = track['id']
    
    # Get track features
    track_features = sp.audio_features(track_id)[0]
    track_features_list.append(track_features)
    
    # Get audio analysis
    audio_analysis = sp.audio_analysis(track_id)
    
    # Flatten the audio_analysis dictionary 
    flattened_analysis = {key: value for key, value in audio_analysis.items() if type(value) in [int, float, str]}
    
    audio_analysis_list.append(flattened_analysis)

# Create DataFrame for track features
track_features_df = pd.DataFrame(track_features_list)

# Create DataFrame for audio analysis
audio_analysis_df = pd.DataFrame(audio_analysis_list)

# Print the DataFrames
print("Track Features:")
print(track_features_df.head())

print("Audio Analysis:")
print(audio_analysis_df.head())
# Out:
# Track Features:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.943   0.558    2    -4.911     1       0.0568        0.0026
# 1         0.711   0.809    2    -4.389     0       0.0955        0.0447
# 2         0.629   0.733    7    -5.445     1       0.0419        0.0025
# 3         0.697   0.820    5    -4.502     1       0.0308        0.1000
# 4         0.629   0.733    7    -5.445     1       0.0419        0.0025
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000002    0.0937    0.606  104.983  audio_features
# 1          0.000000    0.3390    0.816  106.017  audio_features
# 2          0.000000    0.3570    0.362  120.001  audio_features
# 3          0.000000    0.0631    0.502  136.054  audio_features
# 4          0.000000    0.3570    0.362  120.001  audio_features
#
#                        id                                   uri  \
# 0  4xhsWYTOGcal8zt0J161CU  spotify:track:4xhsWYTOGcal8zt0J161CU
# 1  2KslE17cAJNHTsI2MI0jb2  spotify:track:2KslE17cAJNHTsI2MI0jb2
# 2  3Ua0m0YmEjrMi9XErKcNiR  spotify:track:3Ua0m0YmEjrMi9XErKcNiR
# 3  74X2u8JMVooG2QbjRxXwR8  spotify:track:74X2u8JMVooG2QbjRxXwR8
# 4  58BWnoFDNaeM0vwA0K3fqb  spotify:track:58BWnoFDNaeM0vwA0K3fqb
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 1  https://api.spotify.com/v1/tracks/2KslE17cAJNH...
# 2  https://api.spotify.com/v1/tracks/3Ua0m0YmEjrM...
# 3  https://api.spotify.com/v1/tracks/74X2u8JMVooG...
# 4  https://api.spotify.com/v1/tracks/58BWnoFDNaeM...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 1  https://api.spotify.com/v1/audio-analysis/2Ksl...       206020
# 2  https://api.spotify.com/v1/audio-analysis/3Ua0...       212241
# 3  https://api.spotify.com/v1/audio-analysis/74X2...       159080
# 4  https://api.spotify.com/v1/audio-analysis/58BW...       212241
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# Audio Analysis:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]
